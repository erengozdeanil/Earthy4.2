# %%
#SET-UP AND INITIALIZING

import networkx as nx
import copy
import json
import re, requests

# List of definitions:

""" Remove street node function"""
def remove_street_node(nodes_dict, edge_dict, street_node):
    #nodes_dict: Nested dictionary with nodes as keys and its attributes(dict) as values
    #edge_dict: Dict, key as Nodes, Values as all nodes connected to Nodes
    #street_node: As list of nodes representing the streets
    
    edge_dict_streetless = edge_dict.copy()
    k = list(nodes_dict.keys())
    for i in k:
        #for every node in the grid
        for street in street_node:
            #for every street nodes in the street_node list

            if street in edge_dict[i]:
                #if a street node lies in the list of edges within edge_dict
                edge_dict_streetless.pop(i, None)
            
            elif street == i:
                #delete itself because it is a street node
                edge_dict_streetless.pop(i, None)

    return edge_dict_streetless

""" Create a Edges dict in the form of Nodes (keys) : 3 Other neighbouring nodes (values)"""
def create_edge_dict(graph):

    for i, n in G.adjacency():
        edge_dict[i] = list(n)
    return edge_dict
    
""" Find parent of the value in a nested dictionary"""
def find_key(d, value):
    start_list =[]
    for i in value:
        # print("i is", i)
        for k,v in d.items():
            # print("k and v is", k,v)
            if v['name'] == i:
                # print("k is", k)
                start_list.append(i)
    return start_list

""" Gives the value of type key of a node"""
def retrieve_type(list):
    type_list = []
    for i in list:
        # print ("i is", i)
        type = nodes[i]['type']
        # print(tag)
        type_list.append(type)
    return (type_list)

""" Occupies the matched ground floor node with the data from the user"""
def occupy(nodes, x, req):
    nodes[x]['units'] = req['units']
    nodes[x]['tag'] = req['tag']
    nodes[x]['type'] = req['type']
    return nodes

""" De-occupies the ground floor node with the data from the user"""
def unoccupy(nodes, x, req):
    nodes[x]['units'] = None
    nodes[x]['tag'] = None
    nodes[x]['type'] = None
    return nodes

""" Occupies the matched second level node with the data from the user"""
def occupy2(nodes_2, x, req):
    nodes_2[x]['units'] = req['units']
    nodes_2[x]['tag'] = req['tag']
    nodes_2[x]['type'] = req['type']
    return nodes_2

""" De-occupies the second level node with the data from the user"""
def unoccupy2(nodes_2, x, req):
    nodes_2[x]['units'] = None
    nodes_2[x]['tag'] = None
    nodes_2[x]['type'] = None
    return nodes_2

#obtained definition from stack overflow, https://stackoverflow.com/questions/38987/how-do-i-merge-two-dictionaries-in-a-single-expression-taking-union-of-dictiona
def merge_two_dicts(x, y):
    z = x.copy()   # start with keys and values of x
    z.update(y)    # modifies z with keys and values of y
    return z

# %%
#FOUNDATION
# The aim of this script is to import all needed external data, like the results of the survey, the location data of nodes, and the edge information of the nodes.
# this data is imported and edited to be able to use efficiently and clearly throughout the whole code

"""Step 1: Reading JSON file from Rhino GH Export"""

#retrieve nodes.txt from Github (all nodes)
url = "https://raw.githubusercontent.com/erengozdeanil/Earthy4.2/main/0_Configuration/Foundation/nodes.txt"
resp = requests.get(url)
all_nodes = json.loads(resp.text)
#converts keys from str to int
all_nodes = {int(k) : v for k,v in all_nodes.items()}

#retrieve nodes_1.txt from Github (nodes on the ground floor)
url = "https://raw.githubusercontent.com/erengozdeanil/Earthy4.2/main/0_Configuration/Foundation/nodes_1.txt"
resp = requests.get(url)
nodes = json.loads(resp.text)
#converts keys from str to int
nodes = {int(k) : v for k,v in nodes.items()}

#retrieve nodes_2.txt from Github (nodes on the second floor)
url = "https://raw.githubusercontent.com/erengozdeanil/Earthy4.2/main/0_Configuration/Foundation/nodes_2.txt"
resp = requests.get(url)
nodes_2 = json.loads(resp.text)
#converts keys from str to int
nodes_2 = {int(k) : v for k,v in nodes_2.items()}

#retrieve edges.txt from Github
url = "https://raw.githubusercontent.com/erengozdeanil/Earthy4.2/main/0_Configuration/Foundation/edges.txt"
resp = requests.get(url)
edges = json.loads(resp.text)
#converts nested lists into a list of tuples
edges = [tuple(i) for i in edges]
print(nodes[0])

"""Step 2: Intitate Graph, add nodes & edges, determine adjacencies"""
G = nx.Graph()

k = list(nodes.keys())
G.add_nodes_from(k)

G.add_edges_from(edges)
# nx.draw_networkx(G)       #only required to draw if necessary

edge_dict = {}

adj = G.adjacency()

edge_dict = create_edge_dict(G)

"""Step 3: Finding and removing street nodes"""
street_nodes = []

for node, attr in nodes.items():
    #if "tag" = 0 (Local Street), 1 (Medium Street) or 2 (Main Street)
    if attr["tag"] == 0 or attr["tag"] == 1 or attr["tag"] == 2:
        street_nodes.append(node)

edge_dict_streetless = remove_street_node(nodes, edge_dict, street_nodes)


"""Step 4: Retrieve data from survey excel & simplifying data"""
from openpyxl import load_workbook
workbook = load_workbook(filename="Arabic_Dummy_survey_data.xlsx")
workbook.sheetnames
sheet = workbook.active
sheet

# Create list with requests data
p_list=[]

#Simplify requests into:
#[
# district(1-12), 
# "D" - Daily OR "M" - Monthly OR "O" - Occasional, 
# "1" - Shop OR "2" - Shop+Workshop OR "3" - Workshop,
# units required: 1-9,
# name of occupant
# ]
for value in sheet.iter_rows(min_row=3,
                             min_col=6,
                             values_only=True):
    if value[3] != None and value[1] != None and value[2] != None:
        new_value=[int(value[2]), value[1], value[0], int(int(value[3])/9), value[4]]
        if new_value[2]=="Shop":
            new_value[2]="1"
        elif new_value[2]=="Workshop":
            new_value[2]="3"
        elif new_value[2]=="Both shop and workshop":
            new_value[2]="2"
        if new_value[1]=="Daily":
            new_value[1]="D"
        elif new_value[1]=="Monthly":
            new_value[1]="M"
        elif new_value[1]=="Occationally":
            new_value[1]="O"
    
        p_list.append(tuple(new_value))

p_list.sort()

# Create a dictionary from the survey data
user_req = {}

for i in p_list:
    value = {}
    value["name"] = p_list.index(i)
    value["district"] = i[0]
    value["use_frequency"] = i[1]
    value["type"] = i[2]
    value["units"] = i[3]
    value["tag"] = i[4]
    user_req[p_list.index(i)] = value


"""Step 5: Sorting the requirements based on District, Type, Use_Frequency, then Units required
This is to obtain the list in order of priority, from district, then by type (shops > shops+workshop > workshop), then
by use_frequency (Daily > Monthly > Occasional, and lastly by Units (Largest to smallest))
"""

dict_user_req = list(user_req.values())
# user_req_list = sorted(dict_user_req, key=lambda d: (d['district'], d['type'], d['use_frequency'], -d['units']))
user_req_list = sorted(dict_user_req, key=lambda d: (d['district'], d['type'], -d['units']))

# create dictionairy from list again
sorted_user_req = {}

for item in user_req_list:
    sorted_user_req[item['name']] = item
print(sorted_user_req)
# Out:
# {'tag': 1, 'units': None, 'district': 7, 'name': 0, 'use_frequency': 'M', 'type': None}
# {59: {'name': 59, 'district': 7, 'use_frequency': 'D', 'type': '1', 'units': 6, 'tag': 'Izdihaar'}, 194: {'name': 194, 'district': 7, 'use_frequency': 'M', 'type': '1', 'units': 6, 'tag': 'Mujaahid'}, 195: {'name': 195, 'district': 7, 'use_frequency': 'M', 'type': '1', 'units': 6, 'tag': 'Roy'}, 192: {'name': 192, 'district': 7, 'use_frequency': 'M', 'type': '1', 'units': 5, 'tag': 'Aseelah'}, 193: {'name': 193, 'district': 7, 'use_frequency': 'M', 'type': '1', 'units': 5, 'tag': 'Malak'}, 43: {'name': 43, 'district': 7, 'use_frequency': 'D', 'type': '1', 'units': 4, 'tag': 'Asiya'}, 44: {'name': 44, 'district': 7, 'use_frequency': 'D', 'type': '1', 'units': 4, 'tag': 'Basma'}, 45: {'name': 45, 'district': 7, 'use_frequency': 'D', 'type': '1', 'units': 4, 'tag': 'Buthayna'}, 46: {'name': 46, 'district': 7, 'use_frequency': 'D', 'type': '1', 'units': 4, 'tag': 'Faarooq'}, 47: {'name': 47, 'district': 7, 'use_frequency': 'D', 'type': '1', 'units': 4, 'tag': 'Faiza'}, 48: {'name': 48, 'district': 7, 'use_frequency': 'D', 'type': '1', 'units': 4, 'tag': 'Falak'}, 49: {'name': 49, 'district': 7, 'use_frequency': 'D', 'type': '1', 'units': 4, 'tag': 'Faris'}, 50: {'name': 50, 'district': 7, 'use_frequency': 'D', 'type': '1', 'units': 4, 'tag': 'Hadiya'}, 51: {'name': 51, 'district': 7, 'use_frequency': 'D', 'type': '1', 'units': 4, 'tag': 'Haleema'}, 52: {'name': 52, 'district': 7, 'use_frequency': 'D', 'type': '1', 'units': 4, 'tag': 'Hamza'}, 53: {'name': 53, 'district': 7, 'use_frequency': 'D', 'type': '1', 'units': 4, 'tag': 'Hana'}, 54: {'name': 54, 'district': 7, 'use_frequency': 'D', 'type': '1', 'units': 4, 'tag': 'Hessa'}, 55: {'name': 55, 'district': 7, 'use_frequency': 'D', 'type': '1', 'units': 4, 'tag': 'Huda'}, 56: {'name': 56, 'district': 7, 'use_frequency': 'D', 'type': '1', 'units': 4, 'tag': 'Husn'}, 57: {'name': 57, 'district': 7, 'use_frequency': 'D', 'type': '1', 'units': 4, 'tag': 'Kaamil'}, 58: {'name': 58, 'district': 7, 'use_frequency': 'D', 'type': '1', 'units': 4, 'tag': 'Munthir'}, 182: {'name': 182, 'district': 7, 'use_frequency': 'M', 'type': '1', 'units': 4, 'tag': 'Aasmaa'}, 183: {'name': 183, 'district': 7, 'use_frequency': 'M', 'type': '1', 'units': 4, 'tag': 'Ali'}, 184: {'name': 184, 'district': 7, 'use_frequency': 'M', 'type': '1', 'units': 4, 'tag': 'Alia'}, 185: {'name': 185, 'district': 7, 'use_frequency': 'M', 'type': '1', 'units': 4, 'tag': 'Ameena'}, 186: {'name': 186, 'district': 7, 'use_frequency': 'M', 'type': '1', 'units': 4, 'tag': 'Ataa'}, 187: {'name': 187, 'district': 7, 'use_frequency': 'M', 'type': '1', 'units': 4, 'tag': 'Bahiyaa'}, 188: {'name': 188, 'district': 7, 'use_frequency': 'M', 'type': '1', 'units': 4, 'tag': 'Fadl'}, 189: {'name': 189, 'district': 7, 'use_frequency': 'M', 'type': '1', 'units': 4, 'tag': 'Haashim'}, 191: {'name': 191, 'district': 7, 'use_frequency': 'M', 'type': '1', 'units': 4, 'tag': 'Husaam'}, 29: {'name': 29, 'district': 7, 'use_frequency': 'D', 'type': '1', 'units': 3, 'tag': 'Aadab'}, 30: {'name': 30, 'district': 7, 'use_frequency': 'D', 'type': '1', 'units': 3, 'tag': 'Anbar'}, 31: {'name': 31, 'district': 7, 'use_frequency': 'D', 'type': '1', 'units': 3, 'tag': 'Aroob'}, 32: {'name': 32, 'district': 7, 'use_frequency': 'D', 'type': '1', 'units': 3, 'tag': "Baraa'a"}, 33: {'name': 33, 'district': 7, 'use_frequency': 'D', 'type': '1', 'units': 3, 'tag': 'Ghaaliya'}, 34: {'name': 34, 'district': 7, 'use_frequency': 'D', 'type': '1', 'units': 3, 'tag': 'Haala'}, 35: {'name': 35, 'district': 7, 'use_frequency': 'D', 'type': '1', 'units': 3, 'tag': 'Ibtihaaj'}, 36: {'name': 36, 'district': 7, 'use_frequency': 'D', 'type': '1', 'units': 3, 'tag': 'Idrees'}, 37: {'name': 37, 'district': 7, 'use_frequency': 'D', 'type': '1', 'units': 3, 'tag': 'Jaafar'}, 38: {'name': 38, 'district': 7, 'use_frequency': 'D', 'type': '1', 'units': 3, 'tag': 'Jamaal'}, 39: {'name': 39, 'district': 7, 'use_frequency': 'D', 'type': '1', 'units': 3, 'tag': 'Kouther'}, 40: {'na ...

# %% [markdown]
# End of foundation code

# %%
# Organized vertical growth approach

""""Step 1: Determine the maximum depth of building layers on different streets"""

# Max. building extension perpendicular to street:
daily_layers = 3        # Local streets: max. of 3 units behind eachother (9 meter)
monthly_layers = 5      # Medium streets: max. of 5 units behind eachother (15 meter)
occationally_layers = 7 # Main streets: max. of 7 units behind eachother (21 meter)
unassigned_req = {}     # Dict containing all requests which are unassigned
failed = []             # List containing "key" of requests which are unassigned

""""Step 2: Match the user requests with the available nodes on the -ground floor-"""

# Match the user requests with the available nodes
for i, req in sorted_user_req.items():
    print(req["tag"], "begins allocation and needs: ", req["units"])
    # try:    
    #     print(sorted_user_req[i-1]["tag"], "has been assigned: ", occ, " units")
    # except:
    #     pass
    unit_no = req["units"]
    req_frequency = req['use_frequency']
    req_district = req['district']

    # set layer to corresponding street type
    if req_frequency == 'D':
        layer = daily_layers
    elif req_frequency == 'M':
        layer = monthly_layers
    elif req_frequency == 'O':
        layer = occationally_layers

    current_node_list = []      # list of the nodes that have been occupied for one user
    current_node = None         # the node that has been place most recently
    occ = 0                     # the amount of units that have been placed
    failed_nodes = []           # the neighbor nodes that have been tried but didn't match         
    fail_count = 0              # the number of units that have been tried but didn't match
    
    # place the amount of units that is requested
    for count in range(unit_no):   
        # Step 1: Place first unit only on a layer 1 node when occ == 0, to make sure all buildings face the street
        if occ == 0:
            for x, node in nodes.items():
                #this should run for nodes that hasn't been already tested and failed 
                if node not in failed_nodes:
                    if req_frequency == node['use_frequency'] and req_district == node['district'] and node['tag'] == None and node['layer']==1:
                        current_node = x
                        current_node_list.append(x)
                        nodes = occupy(nodes, x, req)
                        occ += 1
                        print(req["tag"], "+1 units")
                        break
        
        # Step 2: This part runs when more than 1 unit is requested
        else:            
            for cur_node in current_node_list:
                if occ != unit_no:
                    neighbour_list = list(G.neighbors(cur_node))
                    #check every neighbour, and find the best node to occupy
                    for neigh in neighbour_list:
                        #check if neighbour is:
                        
                        # A. Available
                        print("Round 1:", nodes[neigh]['tag'])
                        if nodes[neigh]['tag'] == None:
                            # Within the boundary of current street; neigh node['layer'] <= layer
                            if nodes[neigh]['layer'] <= layer:
                                if req_frequency == nodes[neigh]['use_frequency'] and req_district == nodes[neigh]['district']:
                                #Top criteria: to find the deeper node
                                    if  nodes[neigh]['layer'] == nodes[cur_node]['layer'] + 1:
                                        current_node_list.append(neigh)
                                        nodes = occupy(nodes, neigh, req)
                                        occ += 1
                                        print(req["tag"], "+1 units")
                                        break
                            
                        # B. If neighbor nodes 'tag' = 'x', this means that the border of the area is reached (max. distance from intersection) and we start placing at layer 1 nodes again
                        elif nodes[neigh]['tag'] == "x" and ((occ - layer) > -1):
                            neigh_1 = list(G.neighbors(current_node_list[occ - layer]))
                            for n in neigh_1:
                                if nodes[n]['tag'] == None and nodes[n]['layer'] == 1:
                                    current_node_list.append(n)
                                    nodes = occupy(nodes, n, req)
                                    occ += 1
                                    print(req["tag"], "+1 units")
                                    break
                                                    
                        # C. If neighbors position is > layers or not ''x' or occupied: De-occupy all nodes that has been assigned for this person and restart, occ == 0, append node to failed_nodes                 
                        else:
                            #check: If all neighbours dont satisfy conditions, then deoccupy it
                            fail_count += 1
                            print(req["tag"], "+1 fail_count")
                            if fail_count == len(neighbour_list):

                                for j in current_node_list:
                                    print(current_node_list)
                                    unoccupy(nodes, j, req)
                                    print("Deoccupy for ", req["tag"], "begins after ", occ, " placed." "Because ", fail_count == len(neighbour_list), neighbour_list)
                                    break
                                current_node_list = []
                                current_node = None
                                occ = 0
                                fail_count = 0
                                unassigned_req[i] = req
                            break
                                
                        # D. if neighbour is not available, JUST SKIP this neighbour, check next one
    try:    
        print(sorted_user_req[i]["tag"], "has been assigned: ", occ, " units")
    except:
        pass
# Step 3: Establish requests that failed to find a place
for i in unassigned_req:
    failed.append(nodes[i]["name"])

# Measure how many requests have not been fullfilled to create second floor: only when more than 10 requests are to be placed
# And give summary of allocation process
number_unplaced = len(failed)
number_placed = len(list(sorted_user_req)) - number_unplaced

print("Number of placed requests:", number_placed)
print("Number of unplaced requests:", number_unplaced)
print("User index unplaced:", failed)
# Out:
# Izdihaar begins allocation and needs:  6
# Izdihaar +1 units
# Round 1: 1
# Izdihaar +1 fail_count
# Izdihaar has been assigned:  1  units
# Mujaahid begins allocation and needs:  6
# Mujaahid +1 units
# Round 1: 1
# Mujaahid +1 fail_count
# Mujaahid has been assigned:  1  units
# Roy begins allocation and needs:  6
# Roy +1 units
# Round 1: 1
# Roy +1 fail_count
# Roy has been assigned:  1  units
# Aseelah begins allocation and needs:  5
# Aseelah +1 units
# Round 1: 1
# Aseelah +1 fail_count
# Aseelah has been assigned:  1  units
# Malak begins allocation and needs:  5
# Malak +1 units
# Round 1: Aseelah
# Malak +1 fail_count
# Malak has been assigned:  1  units
# Asiya begins allocation and needs:  4
# Asiya +1 units
# Round 1: 1
# Asiya +1 fail_count
# Asiya has been assigned:  1  units
# Basma begins allocation and needs:  4
# Basma +1 units
# Round 1: Asiya
# Basma +1 fail_count
# Basma has been assigned:  1  units
# Buthayna begins allocation and needs:  4
# Buthayna +1 units
# Round 1: Izdihaar
# Buthayna +1 fail_count
# Buthayna has been assigned:  1  units
# Faarooq begins allocation and needs:  4
# Faarooq +1 units
# Round 1: Asiya
# Faarooq +1 fail_count
# Faarooq has been assigned:  1  units
# Faiza begins allocation and needs:  4
# Faiza +1 units
# Round 1: Izdihaar
# Faiza +1 fail_count
# Faiza has been assigned:  1  units
# Falak begins allocation and needs:  4
# Falak +1 units
# Round 1: Malak
# Falak +1 fail_count
# Falak has been assigned:  1  units
# Faris begins allocation and needs:  4
# Faris +1 units
# Round 1: Basma
# Faris +1 fail_count
# Faris has been assigned:  1  units
# Hadiya begins allocation and needs:  4
# Hadiya +1 units
# Round 1: None
# Round 1: 1
# Hadiya +1 fail_count
# Hadiya has been assigned:  1  units
# Haleema begins allocation and needs:  4
# Haleema +1 units
# Round 1: Buthayna
# Haleema +1 fail_count
# Haleema has been assigned:  1  units
# Hamza begins allocation and needs:  4
# Hamza +1 units
# Round 1: Faarooq
# Hamza +1 fail_count
# Hamza has been assigned:  1  units
# Hana begins allocation and needs:  4
# Hana +1 units
# Round 1: Faiza
# Hana +1 fail_count
# Hana has been assigned:  1  units
# Hessa begins allocation and needs:  4
# Hessa +1 units
# Round 1: Falak
# Hessa +1 fail_count
# Hessa has been assigned:  1  units
# Huda begins allocation and needs:  4
# Huda +1 units
# Round 1: Hadiya
# Huda +1 fail_count
# Huda has been assigned:  1  units
# Husn begins allocation and needs:  4
# Husn +1 units
# Round 1: Hamza
# Husn +1 fail_count
# Husn has been assigned:  1  units
# Kaamil begins allocation and needs:  4
# Kaamil +1 units
# Round 1: Hana
# Kaamil +1 fail_count
# Kaamil has been assigned:  1  units
# Munthir begins allocation and needs:  4
# Munthir +1 units
# Round 1: Hessa
# Munthir +1 fail_count
# Munthir has been assigned:  1  units
# Aasmaa begins allocation and needs:  4
# Aasmaa +1 units
# Round 1: Roy
# Aasmaa +1 fail_count
# Aasmaa has been assigned:  1  units
# Ali begins allocation and needs:  4
# Ali +1 units
# Round 1: Haleema
# Ali +1 fail_count
# Ali has been assigned:  1  units
# Alia begins allocation and needs:  4
# Alia +1 units
# Round 1: Faris
# Alia +1 fail_count
# Alia has been assigned:  1  units
# Ameena begins allocation and needs:  4
# Ameena +1 units
# Round 1: 3
# Ameena +1 fail_count
# Ameena has been assigned:  1  units
# Ataa begins allocation and needs:  4
# Ataa +1 units
# Round 1: 3
# Ataa +1 fail_count
# Ataa has been assigned:  1  units
# Bahiyaa begins allocation and needs:  4
# Bahiyaa +1 units
# Round 1: Ameena
# Bahiyaa +1 fail_count
# Bahiyaa has been assigned:  1  units
# Fadl begins allocation and needs:  4
# Fadl +1 units
# Round 1: Ataa
# Fadl +1 fail_count
# Fadl has been assigned:  1  units
# Haashim begins allocation and needs:  4
# Haashim +1 units
# Round 1: Bahiyaa
# Haashim +1 fail_count
# Haashim has been assigned:  1  units
# Husaam begins allocation and needs:  4
# Husaam +1 units
# Round 1: Fadl
# Husaam +1 fail_count
# Husaam has been assigned:  1  units
# Aadab begins allocation and needs:  3
# Aadab +1 units
# Round 1: Huda
# Aadab +1 fail_count
# Aadab has been assigned:  1  units
# Anbar begins allocation and needs:  3
# Anbar +1 units
# Round 1: None
# Anbar +1 units
# Round 1: None
# Round 1: Hessa
# Anbar +1 fail_count
# Anbar has been assigned:  2  units
# Aroob begins allocation and needs:  3
# Aroob +1 units
# Round 1: Husn
# Aroob +1 fail_count
# Aroob has been assigned:  1  units
# Baraa'a begins allocation and needs:  3
# Baraa'a +1 units
# Round 1: None
# Baraa'a +1 units
# Round 1: None
# Round 1: Huda
# Baraa'a +1 fail_count
# Baraa'a has been assigned:  2  units
# Ghaaliya begins allocation and needs:  3
# Ghaaliya +1 units
# Round 1: Kaamil
# Ghaaliya +1 fail_count
# Ghaaliya has been assigned:  1  units
# Haala begins allocation and needs:  3
# Haala +1 units
# Round 1: None
# Haala +1 units
# Round 1: None
# Haala +1 units
# Haala has been assigned:  3  units
# Ibtihaaj begins allocation and needs:  3
# Ibtihaaj +1 units
# Round 1: None
# Ibtihaaj +1 units
# Round 1: None
# Ibtihaaj +1 units
# Ibtihaaj has been assigned:  3  units
# Idrees begins allocation and needs:  3
# Idrees +1 units
# Round 1: Aroob
# Idrees +1 fail_count
# Idrees has been assigned:  1  units
# Jaafar begins allocation and needs:  3
# Jaafar +1 units
# Round 1: Ghaaliya
# Jaafar +1 fail_count
# Jaafar has been assigned:  1  units
# Jamaal begins allocation and needs:  3
# Jamaal +1 units
# Round 1: None
# Jamaal +1 units
# Round 1: Haala
# Jamaal +1 fail_count
# Jamaal has been assigned:  2  units
# Kouther begins allocation and needs:  3
# Kouther +1 units
# Round 1: None
# Kouther +1 units
# Round 1: Ibtihaaj
# Kouther +1 fail_count
# Kouther has been assigned:  2  units
# May begins allocation and needs:  3
# May +1 units
# Round 1: 0
# May +1 fail_count
# May has been assigned:  1  units
# Mutaa begins allocation and needs:  3
# Mutaa +1 units
# Round 1: 0
# Mutaa +1 fail_count
# Mutaa has been assigned:  1  units
# Natheer begins allocation and needs:  3
# Natheer +1 units
# Round 1: Jamaal
# Natheer +1 fail_count
# Natheer has been assigned:  1  units
# Hayat begins allocation and needs:  3
# Hayat +1 units
# Round 1: Haashim
# Hayat +1 fail_count
# Hayat has been assigned:  1  units
# Inas begins allocation and needs:  3
# Inas +1 units
# Round 1: Husaam
# Inas +1 fail_count
# Inas has been assigned:  1  units
# Isaam begins allocation and needs:  3
# Isaam +1 units
# Round 1: None
# Round 1: 1
# Isaam +1 fail_count
# Isaam has been assigned:  1  units
# Nazeeh begins allocation and needs:  3
# Nazeeh +1 units
# Round 1: None
# Round 1: 1
# Nazeeh +1 fail_count
# Nazeeh has been assigned:  1  units
# Ahd begins allocation and needs:  2
# Ahd +1 units
# Round 1: 0
# Ahd +1 fail_count
# Ahd has been assigned:  1  units
# Aida begins allocation and needs:  2
# Aida +1 units
# Round 1: Kouther
# Aida +1 fail_count
# Aida has been assigned:  1  units
# Basheera begins allocation and needs:  2
# Basheera +1 units
# Round 1: 0
# Basheera +1 fail_count
# Basheera has been assigned:  1  units
# Fadheela begins allocation and needs:  2
# Fadheela +1 units
# Round 1: Idrees
# Fadheela +1 fail_count
# Fadheela has been assigned:  1  units
# Fatima begins allocation and needs:  2
# Fatima +1 units
# Round 1: Jaafar
# Fatima +1 fail_count
# Fatima has been assigned:  1  units
# Ghaaliya begins allocation and needs:  2
# Ghaaliya +1 units
# Round 1: 0
# Ghaaliya +1 fail_count
# Ghaaliya has been assigned:  1  units
# Ghusoon begins allocation and needs:  2
# Ghusoon +1 units
# Round 1: 0
# Ghusoon +1 fail_count
# Ghusoon has been assigned:  1  units
# Haniya begins allocation and needs:  2
# Haniya +1 units
# Round 1: Mutaa
# Haniya +1 fail_count
# Haniya has been assigned:  1  units
# Khadeeja begins allocation and needs:  2
# Khadeeja +1 units
# Round 1: May
# Khadeeja +1 fail_count
# Khadeeja has been assigned:  1  units
# Khaleel begins allocation and needs:  2
# Khaleel +1 units
# Round 1: Natheer
# Khaleel +1 fail_count
# Khaleel has been assigned:  1  units
# Madeeha begins allocation and needs:  2
# Madeeha +1 units
# Round 1: Aida
# Madeeha +1 fail_count
# Madeeha has been assigned:  1  units
# Maimoona begins allocation and needs:  2
# Maimoona +1 units
# Round 1: 0
# Maimoona +1 fail_count
# Maimoona has been assigned:  1  units
# Majdy begins allocation and needs:  2
# Majdy +1 units
# Round 1: 0
# Majdy +1 fail_count
# Majdy has been assigned:  1  units
# Masoud begins allocation and needs:  2
# Masoud +1 units
# Round 1: Fadheela
# Masoud +1 fail_count
# Masoud has been assigned:  1  units
# Muaath begins allocation and needs:  2
# Muaath +1 units
# Round 1: Fatima
# Muaath +1 fail_count
# Muaath has been assigned:  1  units
# Muneera begins allocation and needs:  2
# Muneera +1 units
# Round 1: 0
# Muneera +1 fail_count
# Muneera has been assigned:  1  units
# Nooh begins allocation and needs:  2
# Nooh +1 units
# Round 1: 0
# Nooh +1 fail_count
# Nooh has been assigned:  1  units
# Adeela begins allocation and needs:  2
# Adeela +1 units
# Round 1: Inas
# Adeela +1 fail_count
# Adeela has been assigned:  1  units
# Amatullah begins allocation and needs:  2
# Amatullah +1 units
# Round 1: Hayat
# Amatullah +1 fail_count
# Amatullah has been assigned:  1  units
# Arwa begins allocation and needs:  2
# Arwa +1 units
# Round 1: Adeela
# Arwa +1 fail_count
# Arwa has been assigned:  1  units
# Baasima begins allocation and needs:  2
# Baasima +1 units
# Round 1: Isaam
# Baasima +1 fail_count
# Baasima has been assigned:  1  units
# Bierocracy begins allocation and needs:  2
# Bierocracy +1 units
# Round 1: Amatullah
# Bierocracy +1 fail_count
# Bierocracy has been assigned:  1  units
# Iman begins allocation and needs:  2
# Iman +1 units
# Round 1: Nazeeh
# Iman +1 fail_count
# Iman has been assigned:  1  units
# Intisaar begins allocation and needs:  2
# Intisaar +1 units
# Round 1: Iman
# Intisaar +1 fail_count
# Intisaar has been assigned:  1  units
# Kareema begins allocation and needs:  2
# Kareema +1 units
# Round 1: Arwa
# Kareema +1 fail_count
# Kareema has been assigned:  1  units
# Kawthar begins allocation and needs:  2
# Kawthar +1 units
# Round 1: Bierocracy
# Kawthar +1 fail_count
# Kawthar has been assigned:  1  units
# Kulthoom begins allocation and needs:  2
# Kulthoom +1 units
# Round 1: Baasima
# Kulthoom +1 fail_count
# Kulthoom has been assigned:  1  units
# Ma'n begins allocation and needs:  2
# Ma'n +1 units
# Round 1: Kareema
# Ma'n +1 fail_count
# Ma'n has been assigned:  1  units
# Majd begins allocation and needs:  2
# Majd +1 units
# Round 1: Kulthoom
# Majd +1 fail_count
# Majd has been assigned:  1  units
# Moosa begins allocation and needs:  2
# Moosa +1 units
# Round 1: Kawthar
# Moosa +1 fail_count
# Moosa has been assigned:  1  units
# Muayid begins allocation and needs:  2
# Muayid +1 units
# Round 1: Intisaar
# Muayid +1 fail_count
# Muayid has been assigned:  1  units
# Mutasim begins allocation and needs:  2
# Mutasim has been assigned:  0  units
# Qutaybah begins allocation and needs:  2
# Qutaybah has been assigned:  0  units
# Rajab begins allocation and needs:  2
# Rajab has been assigned:  0  units
# Anees begins allocation and needs:  1
# Anees +1 units
# Anees has been assigned:  1  units
# Azza begins allocation and needs:  1
# Azza +1 units
# Azza has been assigned:  1  units
# Baasim begins allocation and needs:  1
# Baasim +1 units
# Baasim has been assigned:  1  units
# Balqis begins allocation and needs:  1
# Balqis +1 units
# Balqis has been assigned:  1  units
# Ghusoon begins allocation and needs:  1
# Ghusoon +1 units
# Ghusoon has been assigned:  1  units
# Haifa begins allocation and needs:  1
# Haifa +1 units
# Haifa has been assigned:  1  units
# Haneefa begins allocation and needs:  1
# Haneefa +1 units
# Haneefa has been assigned:  1  units
# Janaan begins allocation and needs:  1
# Janaan +1 units
# Janaan has been assigned:  1  units
# Jun begins allocation and needs:  1
# Jun +1 units
# Jun has been assigned:  1  units
# Khawlah begins allocation and needs:  1
# Khawlah +1 units
# Khawlah has been assigned:  1  units
# Lutfi begins allocation and needs:  1
# Lutfi +1 units
# Lutfi has been assigned:  1  units
# Maraam begins allocation and needs:  1
# Maraam +1 units
# Maraam has been assigned:  1  units
# Afrah begins allocation and needs:  1
# Afrah has been assigned:  0  units
# Ayman begins allocation and needs:  1
# Ayman has been assigned:  0  units
# Bahiy Udeen begins allocation and needs:  1
# Bahiy Udeen has been assigned:  0  units
# Dhuha begins allocation and needs:  1
# Dhuha has been assigned:  0  units
# Fawziya begins allocation and needs:  1
# Fawziya has been assigned:  0  units
# Firyal begins allocation and needs:  1
# Firyal has been assigned:  0  units
# Lamya begins allocation and needs:  1
# Lamya has been assigned:  0  units
# Mufeeda begins allocation and needs:  1
# Mufeeda has been assigned:  0  units
# Naasih begins allocation and needs:  1
# Naasih has been assigned:  0  units
# Omeir begins allocation and needs:  1
# Omeir has been assigned:  0  units
# Eren begins allocation and needs:  9
# Eren +1 units
# Round 1: Haifa
# Eren +1 fail_count
# Eren has been assigned:  1  units
# Firdoos begins allocation and needs:  6
# Firdoos +1 units
# Round 1: Ghusoon
# Firdoos +1 fail_count
# Firdoos has been assigned:  1  units
# Asma begins allocation and needs:  6
# Asma has been assigned:  0  units
# Khaldoon begins allocation and needs:  6
# Khaldoon has been assigned:  0  units
# Fareeda begins allocation and needs:  5
# Fareeda has been assigned:  0  units
# Faakhir begins allocation and needs:  4
# Faakhir +1 units
# Round 1: Khawlah
# Faakhir +1 fail_count
# Faakhir has been assigned:  1  units
# Ghaaliya begins allocation and needs:  4
# Ghaaliya +1 units
# Round 1: Jun
# Ghaaliya +1 fail_count
# Ghaaliya has been assigned:  1  units
# Hasna begins allocation and needs:  4
# Hasna +1 units
# Round 1: Lutfi
# Hasna +1 fail_count
# Hasna has been assigned:  1  units
# Inaam begins allocation and needs:  4
# Inaam +1 units
# Round 1: Maraam
# Inaam +1 fail_count
# Inaam has been assigned:  1  units
# Khalida begins allocation and needs:  4
# Khalida +1 units
# Round 1: Eren
# Khalida +1 fail_count
# Khalida has been assigned:  1  units
# Majida begins allocation and needs:  4
# Majida +1 units
# Round 1: Firdoos
# Majida +1 fail_count
# Majida has been assigned:  1  units
# Muhannad begins allocation and needs:  4
# Muhannad +1 units
# Round 1: Faakhir
# Muhannad +1 fail_count
# Muhannad has been assigned:  1  units
# Muwafaq begins allocation and needs:  4
# Muwafaq +1 units
# Round 1: Ghaaliya
# Muwafaq +1 fail_count
# Muwafaq has been assigned:  1  units
# Omar begins allocation and needs:  4
# Omar +1 units
# Round 1: Hasna
# Omar +1 fail_count
# Omar has been assigned:  1  units
# Aalia begins allocation and needs:  4
# Aalia has been assigned:  0  units
# Afaf begins allocation and needs:  4
# Afaf has been assigned:  0  units
# Ahlam begins allocation and needs:  4
# Ahlam has been assigned:  0  units
# Amal begins allocation and needs:  4
# Amal has been assigned:  0  units
# Hooriya begins allocation and needs:  4
# Hooriya has been assigned:  0  units
# Leena begins allocation and needs:  4
# Leena has been assigned:  0  units
# Mamnoon begins allocation and needs:  4
# Mamnoon has been assigned:  0  units
# Aamaal begins allocation and needs:  3
# Aamaal +1 units
# Round 1: Inaam
# Aamaal +1 fail_count
# Aamaal has been assigned:  1  units
# Ahmad begins allocation and needs:  3
# Ahmad +1 units
# Round 1: Muhannad
# Ahmad +1 fail_count
# Ahmad has been assigned:  1  units
# Ameera begins allocation and needs:  3
# Ameera +1 units
# Round 1: Khalida
# Ameera +1 fail_count
# Ameera has been assigned:  1  units
# Haaroon begins allocation and needs:  3
# Haaroon +1 units
# Round 1: Majida
# Haaroon +1 fail_count
# Haaroon has been assigned:  1  units
# Hadiya begins allocation and needs:  3
# Hadiya +1 units
# Round 1: Muwafaq
# Hadiya +1 fail_count
# Hadiya has been assigned:  1  units
# Ikraam begins allocation and needs:  3
# Ikraam +1 units
# Round 1: Omar
# Ikraam +1 fail_count
# Ikraam has been assigned:  1  units
# Kaamla begins allocation and needs:  3
# Kaamla +1 units
# Round 1: Aamaal
# Kaamla +1 fail_count
# Kaamla has been assigned:  1  units
# Najeeb begins allocation and needs:  3
# Najeeb +1 units
# Round 1: Ahmad
# Najeeb +1 fail_count
# Najeeb has been assigned:  1  units
# Anaan begins allocation and needs:  3
# Anaan has been assigned:  0  units
# Anwaar begins allocation and needs:  3
# Anwaar has been assigned:  0  units
# Imraan begins allocation and needs:  3
# Imraan has been assigned:  0  units
# Noori begins allocation and needs:  3
# Noori has been assigned:  0  units
# Abu Bakr begins allocation and needs:  2
# Abu Bakr +1 units
# Round 1: Hadiya
# Abu Bakr +1 fail_count
# Abu Bakr has been assigned:  1  units
# Ayeh begins allocation and needs:  2
# Ayeh +1 units
# Round 1: Ikraam
# Ayeh +1 fail_count
# Ayeh has been assigned:  1  units
# Badriya begins allocation and needs:  2
# Badriya +1 units
# Round 1: Kaamla
# Badriya +1 fail_count
# Badriya has been assigned:  1  units
# Faatin begins allocation and needs:  2
# Faatin +1 units
# Round 1: Haaroon
# Faatin +1 fail_count
# Faatin has been assigned:  1  units
# Iesa begins allocation and needs:  2
# Iesa +1 units
# Round 1: Ameera
# Iesa +1 fail_count
# Iesa has been assigned:  1  units
# Jala begins allocation and needs:  2
# Jala has been assigned:  0  units
# Kameela begins allocation and needs:  2
# Kameela has been assigned:  0  units
# Khairiya begins allocation and needs:  2
# Khairiya has been assigned:  0  units
# Lama begins allocation and needs:  2
# Lama has been assigned:  0  units
# Muhja begins allocation and needs:  2
# Muhja has been assigned:  0  units
# Aamir begins allocation and needs:  2
# Aamir has been assigned:  0  units
# Baha Udeen begins allocation and needs:  2
# Baha Udeen has been assigned:  0  units
# Banan begins allocation and needs:  2
# Banan has been assigned:  0  units
# Dawoud begins allocation and needs:  2
# Dawoud has been assigned:  0  units
# Ghusoon begins allocation and needs:  2
# Ghusoon has been assigned:  0  units
# Hameeda begins allocation and needs:  2
# Hameeda has been assigned:  0  units
# Jameel begins allocation and needs:  2
# Jameel has been assigned:  0  units
# Manaar begins allocation and needs:  2
# Manaar has been assigned:  0  units
# Maysaa begins allocation and needs:  2
# Maysaa has been assigned:  0  units
# Amr begins allocation and needs:  1
# Amr has been assigned:  0  units
# Asah begins allocation and needs:  1
# Asah has been assigned:  0  units
# Haadiya begins allocation and needs:  1
# Haadiya has been assigned:  0  units
# Hind begins allocation and needs:  1
# Hind has been assigned:  0  units
# Ihsaan begins allocation and needs:  1
# Ihsaan has been assigned:  0  units
# Lubaaba begins allocation and needs:  1
# Lubaaba has been assigned:  0  units
# Mahdy begins allocation and needs:  1
# Mahdy has been assigned:  0  units
# Rabee' begins allocation and needs:  1
# Rabee' has been assigned:  0  units
# Batool begins allocation and needs:  1
# Batool has been assigned:  0  units
# Faatina begins allocation and needs:  1
# Faatina has been assigned:  0  units
# Fareed begins allocation and needs:  1
# Fareed has been assigned:  0  units
# Ghaazi begins allocation and needs:  1
# Ghaazi has been assigned:  0  units
# Marwan begins allocation and needs:  1
# Marwan has been assigned:  0  units
# Muna begins allocation and needs:  1
# Muna has been assigned:  0  units
# Muntasir begins allocation and needs:  1
# Muntasir has been assigned:  0  units
# Manaal begins allocation and needs:  8
# Manaal has been assigned:  0  units
# Bushra begins allocation and needs:  6
# Bushra has been assigned:  0  units
# Fareeha begins allocation and needs:  6
# Fareeha has been assigned:  0  units
# Lateefa begins allocation and needs:  6
# Lateefa has been assigned:  0  units
# Makaarim begins allocation and needs:  6
# Makaarim has been assigned:  0  units
# Jawad begins allocation and needs:  6
# Jawad has been assigned:  0  units
# Basel begins allocation and needs:  5
# Basel has been assigned:  0  units
# Nabeeh begins allocation and needs:  5
# Nabeeh has been assigned:  0  units
# Ablaa begins allocation and needs:  4
# Ablaa has been assigned:  0  units
# Afraa begins allocation and needs:  4
# Afraa has been assigned:  0  units
# Alaa begins allocation and needs:  4
# Alaa has been assigned:  0  units
# Amani begins allocation and needs:  4
# Amani has been assigned:  0  units
# Areebah begins allocation and needs:  4
# Areebah has been assigned:  0  units
# Bishr begins allocation and needs:  4
# Bishr has been assigned:  0  units
# Ghaalib begins allocation and needs:  4
# Ghaalib has been assigned:  0  units
# Lamees begins allocation and needs:  4
# Lamees has been assigned:  0  units
# Mayyada  begins allocation and needs:  4
# Mayyada  has been assigned:  0  units
# Ragheb begins allocation and needs:  4
# Ragheb has been assigned:  0  units
# Haala begins allocation and needs:  4
# Haala has been assigned:  0  units
# Hadiya begins allocation and needs:  4
# Hadiya has been assigned:  0  units
# Hanan begins allocation and needs:  4
# Hanan has been assigned:  0  units
# Houd begins allocation and needs:  4
# Houd has been assigned:  0  units
# Izz Udeen begins allocation and needs:  4
# Izz Udeen has been assigned:  0  units
# Naadir begins allocation and needs:  4
# Naadir has been assigned:  0  units
# Aasim begins allocation and needs:  3
# Aasim has been assigned:  0  units
# Aisha begins allocation and needs:  3
# Aisha has been assigned:  0  units
# Areej begins allocation and needs:  3
# Areej has been assigned:  0  units
# Diyaa Udeen begins allocation and needs:  3
# Diyaa Udeen has been assigned:  0  units
# Fadwa begins allocation and needs:  3
# Fadwa has been assigned:  0  units
# Ghaada begins allocation and needs:  3
# Ghaada has been assigned:  0  units
# Ilhaam begins allocation and needs:  3
# Ilhaam has been assigned:  0  units
# Imaad begins allocation and needs:  3
# Imaad has been assigned:  0  units
# Imtithal begins allocation and needs:  3
# Imtithal has been assigned:  0  units
# Inaya begins allocation and needs:  3
# Inaya has been assigned:  0  units
# Maysoon begins allocation and needs:  3
# Maysoon has been assigned:  0  units
# Azhar begins allocation and needs:  3
# Azhar has been assigned:  0  units
# Fahad begins allocation and needs:  3
# Fahad has been assigned:  0  units
# Maazin begins allocation and needs:  3
# Maazin has been assigned:  0  units
# Maisa begins allocation and needs:  3
# Maisa has been assigned:  0  units
# Aneesa begins allocation and needs:  2
# Aneesa has been assigned:  0  units
# Asalah begins allocation and needs:  2
# Asalah has been assigned:  0  units
# Azhaar begins allocation and needs:  2
# Azhaar has been assigned:  0  units
# Baheera begins allocation and needs:  2
# Baheera has been assigned:  0  units
# Baseema begins allocation and needs:  2
# Baseema has been assigned:  0  units
# Haala begins allocation and needs:  2
# Haala has been assigned:  0  units
# Hayaam begins allocation and needs:  2
# Hayaam has been assigned:  0  units
# Jameela begins allocation and needs:  2
# Jameela has been assigned:  0  units
# Khulood begins allocation and needs:  2
# Khulood has been assigned:  0  units
# Mahmoud begins allocation and needs:  2
# Mahmoud has been assigned:  0  units
# Qasim begins allocation and needs:  2
# Qasim has been assigned:  0  units
# Fawaz begins allocation and needs:  2
# Fawaz has been assigned:  0  units
# Haady begins allocation and needs:  2
# Haady has been assigned:  0  units
# Huma begins allocation and needs:  2
# Huma has been assigned:  0  units
# Humam begins allocation and needs:  2
# Humam has been assigned:  0  units
# Labeeb begins allocation and needs:  2
# Labeeb has been assigned:  0  units
# Abeer begins allocation and needs:  1
# Abeer has been assigned:  0  units
# Almas begins allocation and needs:  1
# Almas has been assigned:  0  units
# Ameer begins allocation and needs:  1
# Ameer has been assigned:  0  units
# Awad begins allocation and needs:  1
# Awad has been assigned:  0  units
# Azeeza begins allocation and needs:  1
# Azeeza has been assigned:  0  units
# Badr Udeen begins allocation and needs:  1
# Badr Udeen has been assigned:  0  units
# Felipe begins allocation and needs:  1
# Felipe has been assigned:  0  units
# Haatim begins allocation and needs:  1
# Haatim has been assigned:  0  units
# Kawkab begins allocation and needs:  1
# Kawkab has been assigned:  0  units
# Khairy begins allocation and needs:  1
# Khairy has been assigned:  0  units
# Maha begins allocation and needs:  1
# Maha has been assigned:  0  units
# Maryam begins allocation and needs:  1
# Maryam has been assigned:  0  units
# Mawiya begins allocation and needs:  1
# Mawiya has been assigned:  0  units
# Musheera begins allocation and needs:  1
# Musheera has been assigned:  0  units
# Muslim begins allocation and needs:  1
# Muslim has been assigned:  0  units
# Nasser Udeen begins allocation and needs:  1
# Nasser Udeen has been assigned:  0  units
# Ghaydaa begins allocation and needs:  1
# Ghaydaa has been assigned:  0  units
# Jumaana begins allocation and needs:  1
# Jumaana has been assigned:  0  units
# Muhsin begins allocation and needs:  1
# Muhsin has been assigned:  0  units
# Najm Udeen begins allocation and needs:  1
# Najm Udeen has been assigned:  0  units
# Qays begins allocation and needs:  1
# Qays has been assigned:  0  units
# Number of placed requests: 247
# Number of unplaced requests: 0
# User index unplaced: []

# %%
# locate stair nodes
stair_nodes=[]
for i in nodes:
        if nodes[i]["tag"]==3:
            stair_nodes.append(i)
print("Stair nodes are:",stair_nodes)

# find street nodes
street_nodes=[]
for i in nodes:
    if nodes[i]["tag"]==1:
        street_nodes.append(i)
print("Street nodes are:", street_nodes)

# for i in street_nodes:
#     node=i
#     radius=5
# stair_radius = nx.generators.ego_graph(G, node, radius=radius)
# nx.draw_networkx(stair_radius)

# get nodes to occupy from the graph
# stair_nodes=list(stair_radius.nodes)
# print("stair nodes are:", stair_nodes)

# # remove street nodes
# for k in stair_nodes:
#     for i in street_nodes:
#         if i == k:
#             stair_nodes.remove(k)
# stair_nodes

# # remove street neighboring nodes from neighboring nodes
# for i in stair_nodes:
#     for k in street_nodes:
#         for j in edge_dict[k]:
#             if j==i:
#                 # print(i)
#                 stair_nodes.remove(i)
# stair_nodes

# add attributes to nodes
nodes[i]["module"]=[]
for i in stair_nodes:
    nodes[i]["tag"]=3
for i in stair_nodes:
    nodes[i]["type"]="Stair"
for i in stair_nodes:
    nodes[i]["module"]=7

## locate the walkway on the second floor (walkway: "tag" = 4)
sec_path = []           # sec_path contains all nodes that form the walkway at the second floor

for k in nodes_2:
    try:
        if nodes_2[k]["layer"] == 1:
            nodes_2[k]["tag"] = 4
            sec_path.append(nodes_2[k])
    except:
        pass
# print(sec_path)
# print(nodes_2[640])
# Out:
# Stair nodes are: [83, 84, 97, 99, 118, 119, 140, 141, 171, 172]
# Street nodes are: [0, 1, 2, 3, 4, 5, 12, 13, 14, 15, 26, 27, 28, 29, 51, 52, 53, 55, 78, 79, 80, 81, 111, 112, 113, 114, 154, 155, 156, 157, 193, 194, 195, 196, 250, 251, 252, 253, 297, 298, 299, 300, 352, 353, 354, 355, 411, 412, 413, 414, 468, 469, 470, 471, 528, 529, 530, 531]

# %%
""""Step 3: Match the user requests with the available nodes on the -second floor-"""

# Max. building extension perpendicular to street:
daily_layers = 3        # Local streets: max. of 3 units behind eachother (9 meter)
monthly_layers = 5      # Medium streets: max. of 5 units behind eachother (15 meter)
occationally_layers = 7 # Main streets: max. of 7 units behind eachother (21 meter)
nodes_count_1 = 580     # nodes at second floor level start from here
unassigned_final = {}   # Dict containing all requests which are unassigned again

if number_unplaced > 10:
    # Match the user requests with the available nodes
    for i, req in unassigned_req.items():
        counter = 0
        unit_no = req["units"]
        req_frequency = req['use_frequency']
        req_district = req['district']

        # set layer to corresponding street type
        if req_frequency == 'D':
            layer = daily_layers
        elif req_frequency == 'M':
            layer = monthly_layers
        elif req_frequency == 'O':
            layer = occationally_layers

        current_node_list = []      # list of the nodes that have been occupied for one user
        current_node = None         # the node that has been place most recently
        occ = 0                     # the amount of units that have been placed
        failed_nodes2 = []           # the neighbor nodes that have been tried but didn't match         
        fail_count = 0              # the number of units that have been tried but didn't match
        
        # place the amount of units that is requested
        for count in range(unit_no):   
            # Step 1: Place first unit only on a layer 2 node when occ == 0, to make sure all buildings face the street
            if occ == 0:
                for x, node in nodes_2.items():
                    #this should run for nodes that hasn't been already tested and failed AND if the node below is occupied
                    not_none = nodes[node["name"] - nodes_count_1]["tag"] != None
                    not_stairs = nodes[node["name"] - nodes_count_1]["tag"] != 3
                    
                    if node not in failed_nodes2 and not_none and not_stairs:
                        if req_frequency == node['use_frequency'] and req_district == node['district'] and node['tag'] == None and node['layer']==2:
                            current_node = x
                            current_node_list.append(x)
                            nodes_2 = occupy2(nodes_2, x, req)
                            occ += 1
                            break
            
            # Step 2: This part runs when more than 1 unit is requested
            else:            
                for cur_node in current_node_list:
                    if occ != unit_no:
                        neighbour_list = list(G.neighbors(cur_node))
                        #check every neighbour, and find the best node to occupy
                        for neigh in neighbour_list:
                            #check if neighbour is:
                            
                            # A. Available
                            if nodes_2[neigh]['tag'] == None:
                                # Within the boundary of current street; neigh node['layer'] <= layer
                                if nodes_2[neigh]['layer'] <= layer:
                                    if req_frequency == nodes_2[neigh]['use_frequency'] and req_district == nodes_2[neigh]['district']:
                                    #Top criteria: to find the deeper node
                                        if  nodes_2[neigh]['layer'] == nodes_2[cur_node]['layer'] + 1 and nodes[((nodes_2[neigh]['name']) - nodes_count_1)]["tag"] != None and nodes[((nodes_2[neigh]['name']) - nodes_count_1)]["tag"] != 3:
                                            current_node_list.append(neigh)
                                            nodes_2 = occupy2(nodes_2, neigh, req)
                                            occ += 1
                                            break
                                
                            # B. If neighbor nodes 'tag' = 'x', this means that the border of the area is reached (max. distance from intersection) and we start placing at layer 1 nodes again
                            elif nodes_2[neigh]['tag'] == "x" and ((occ - layer) > -1):
                                neigh_1 = list(G.neighbors(current_node_list[occ - layer]))
                                for n in neigh_1:
                                    if nodes_2[n]['tag'] == None and nodes_2[n]['layer'] == 1:
                                        current_node_list.append(n)
                                        nodes_2 = occupy2(nodes_2, n, req)
                                        occ += 1
                                        break
                                                        
                            # C. If neighbors position is > layers or not ''x' or occupied: De-occupy all nodes that has been assigned for this person and restart, occ == 0, append node to failed_nodes                 
                            else:
                                fail_count += 1
                            
                                #check: If all neighbours dont satisfy conditions, then deoccupy it
                                if fail_count == len(neighbour_list):
                                    for j in current_node_list:
                                        unoccupy2(nodes_2, j, req)
                                    current_node_list = []
                                    current_node = None
                                    occ = 0
                                    unassigned_final[i] = req
                                    break
                                    
                            # 2. if neighbour is not available, JUST SKIP this neighbour, check next one

failed_2 = []
print(unassigned_final)
for i in unassigned_final:
    failed_2.append(unassigned_req[i]["name"])
number_unplaced_2=len(failed_2)

print("Number of unplaced requests:", number_unplaced_2)
print(unassigned_final.keys())
print("User identities:", failed_2)
print("\n")
# Out:
# {}
# Number of unplaced requests: 0
# dict_keys([])
# User identities: []

# %%
"""Step 4: ____"""
for j in nodes_2:
    for i in nodes:
        if nodes[i]["tag"]==1:
            nodes_2[i+nodes_count_1]["tag"]==1
        elif nodes[i]["tag"]==2:
            nodes_2[i+nodes_count_1]["tag"]==2
        elif nodes[i]["tag"]==0: 
            nodes_2[i+nodes_count_1]["tag"]==0
            
"""Assigning "floor" attributes to all nodes"""

for k in nodes:
    nodes[k]['floor'] = None

for i in nodes:
    if (nodes_2[i+nodes_count_1]['tag'] == None) or (nodes_2[i+nodes_count_1]['tag'] == "x") or (nodes_2[i+nodes_count_1]['tag'] == 1) or (nodes_2[i+nodes_count_1]['tag'] == 2) or (nodes_2[i+nodes_count_1]['tag'] == 0) :
        # print(nodes_2[i+580])
        nodes[i]['floor'] = 0
    else:
        nodes[i]['floor'] = 1

for j in nodes_2:
    nodes_2[j]['floor'] = 0

"""Combining Ground and Level 1 nodes together and Exporting it together"""
nodes_final = merge_two_dicts(nodes, nodes_2)

file = "211024_nodes_occupied.txt"
with open(str(file), 'w') as outfile:
    try:
        json.dump(nodes_final, outfile)
        print(file + " has been updated successfully")
    except:
        print("Problem with updating file")
# Out:
# 211024_nodes_occupied.txt has been updated successfully

# %% [markdown]
# End of foundation code
